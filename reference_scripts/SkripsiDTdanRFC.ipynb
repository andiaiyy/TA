# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/ALLFLOWMETER_HIKARI2021.csv')

# %%
df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1, inplace=True)

# %%
df_exclude_object = df.select_dtypes(exclude=['object'])

# %%
X = df_exclude_object.iloc[:,:-1]
y = df_exclude_object.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-156c33d711d3> in <module>
# ----> 1 dtree = DecisionTreeClassifier()
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94    155219
#            1       0.11      0.11      0.11     11365
#
#     accuracy                           0.88    166584
#    macro avg       0.52      0.52      0.52    166584
# weighted avg       0.88      0.88      0.88    166584

# %%
labels = ["Benign", "Malicious"]
cm = confusion_matrix(y_test, pred_dtc)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap="viridis", values_format='');

# %% [markdown]
# #Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc = rfc.predict(X_test)

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94    155219
#            1       0.14      0.12      0.13     11365
#
#     accuracy                           0.89    166584
#    macro avg       0.54      0.53      0.54    166584
# weighted avg       0.88      0.89      0.89    166584

# %%
labels = ["Benign", "Malicious"]
cm = confusion_matrix(y_test, pred_rfc)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap="viridis", values_format='');
