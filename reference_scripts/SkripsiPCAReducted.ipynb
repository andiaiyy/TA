# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/ALLFLOWMETER_HIKARI2021.csv')

# %%
df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1, inplace=True)

# %%
df.shape
# Out:
# (555278, 86)

# %%
df_exclude_object = df.select_dtypes(exclude=['object'])

# %%
df_exclude_object['Label'].value_counts()
# Out:
# 0    517582
# 1     37696
# Name: Label, dtype: int64

# %%
df_exclude_object.shape
# Out:
# (555278, 82)

# %%
df_exclude_object.head(5)
# Out:
#    originp  responp  flow_duration  fwd_pkts_tot  bwd_pkts_tot  \
# 0    13316      443       2.207588            15            14
# 1    13318      443      15.624266            15            14
# 2    13320      443      12.203357            14            13
# 3    13322      443       9.992448            14            13
# 4    13324      443       7.780611            14            14
#
#    fwd_data_pkts_tot  bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# 0                  6                  6          6.794746          6.341763
# 1                  6                  6          0.960045          0.896042
# 2                  6                  5          1.147225          1.065281
# 3                  6                  5          1.401058          1.300983
# 4                  6                  5          1.799345          1.799345
#
#    flow_pkts_per_sec  ...     active.std      idle.min      idle.max  \
# 0          13.136509  ...       0.000000  0.000000e+00  0.000000e+00
# 1           1.856087  ...  158109.181742  1.534300e+07  1.534300e+07
# 2           2.212506  ...  125449.251656  1.196814e+07  1.196814e+07
# 3           2.702041  ...  123182.931318  9.759205e+06  9.759205e+06
# 4           3.598689  ...  126016.885411  7.545305e+06  7.545305e+06
#
#        idle.tot      idle.avg  idle.std  fwd_init_window_size  \
# 0  0.000000e+00  0.000000e+00       0.0                 29200
# 1  1.534300e+07  1.534300e+07       0.0                 29200
# 2  1.196814e+07  1.196814e+07       0.0                 29200
# 3  9.759205e+06  9.759205e+06       0.0                 29200
# 4  7.545305e+06  7.545305e+06       0.0                 29200
#
#    bwd_init_window_size  fwd_last_window_size  Label
# 0                 65160                     0      1
# 1                 65160                     0      1
# 2                 65160                     0      1
# 3                 65160                     0      1
# 4                 65160                     0      1
#
# [5 rows x 82 columns]

# %%
# Sample figsize in inches
fig, ax = plt.subplots(figsize=(20,10))
# Imbalanced DataFrame Correlation
corr = df_exclude_object.corr()
sns.heatmap(corr, cmap='YlGnBu', annot_kws={'size':30}, ax=ax)
ax.set_title("Imbalanced Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# #StandardScaler
# mengubah fitur menjadi single unit variance

# %%
#pake PCA utk cari 2 principle components
from sklearn.preprocessing import StandardScaler

# %%
#kita mau pastikan setiap feature kita itu hanya single unit variance
scaler = StandardScaler()
scaler.fit(df_exclude_object.iloc[:,:-1])
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(df_exclude_object.iloc[:,:-1])

# %% [markdown]
# #PCA
# reduksi dimensi

# %% [markdown]
# ##Menjadi 2 principal components

# %%
#PCA
from sklearn.decomposition import PCA

# %%
pca_2 = PCA(n_components = 2) #mencari 2 principle components

# %%
pca_2.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca_2 = pca_2.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (555278, 81)

# %%
x_pca_2.shape
# Out:
# (555278, 2)

# %%
plt.figure(figsize=(10,6))
plt.scatter(x_pca_2[:, 0], x_pca_2[:, 1], c=df['Label'], cmap = 'viridis')
plt.xlabel('First Principle Component')
plt.ylabel('Second Principle Component')
# Out:
# Text(0, 0.5, 'Second Principle Component')

# %%
pca_2.components_
# Out:
# array([[-2.06882748e-03, -2.89162141e-02,  8.56127607e-02,
#          7.60491543e-02,  7.75979481e-02,  7.86609171e-02,
#          7.49593829e-02, -3.31066137e-02, -3.36332111e-02,
#         -3.41675777e-02,  6.29501190e-02,  7.51889218e-02,
#          1.28439347e-01,  1.90032456e-01,  7.68849223e-02,
#          1.91285361e-01,  2.04878455e-01,  2.07290808e-01,
#          1.87699440e-01,  1.15126932e-01,  7.93558127e-02,
#          9.24134591e-02,  7.69393910e-02, -2.80385792e-05,
#         -3.59186908e-04, -3.31039099e-03, -6.68201106e-04,
#         -1.22115227e-01,  1.84755176e-01,  7.12494769e-02,
#          9.01419008e-02,  1.73962007e-01, -1.18180948e-01,
#          1.84053420e-01,  9.25356001e-02,  1.81619701e-01,
#          1.95962865e-01, -1.22107276e-01,  1.84119922e-01,
#          9.56887540e-02,  1.86107394e-01,  1.98118349e-01,
#         -9.68416293e-03,  1.35547704e-01,  8.52235371e-02,
#          1.49958712e-02,  1.34780510e-01,  7.67208118e-04,
#          1.45382549e-01,  1.05826196e-01,  1.17439353e-01,
#          1.35048345e-01, -9.74110506e-03,  1.36363746e-01,
#          8.56356963e-02,  3.12822234e-03,  1.34497286e-01,
#          1.05172587e-02,  1.02923265e-01,  1.03369819e-01,
#          6.59194924e-02,  1.03728046e-01,  2.54499716e-02,
#          7.69400392e-02,  3.39043896e-02,  8.16732374e-02,
#          1.00006903e-02,  6.55086904e-02,  8.04317914e-02,
#          5.78684368e-02,  6.68407696e-02,  6.86170627e-02,
#          3.99858092e-02,  1.05882437e-01,  1.35115318e-01,
#          7.03937006e-02,  1.24017674e-01,  8.97978638e-02,
#          1.72039855e-01,  1.92802373e-01, -2.50856179e-02],
#        [ 4.27887373e-02,  2.57979512e-02, -7.24512228e-02,
#          1.43647477e-01,  1.45662911e-01,  1.32215293e-01,
#          1.45092209e-01,  2.96669662e-02,  3.13628062e-02,
#          3.12152365e-02,  3.53199333e-02,  1.42274013e-01,
#          3.81971856e-02,  4.30042081e-02,  1.45414266e-01,
#          4.83717177e-02,  3.68921198e-02,  1.80444163e-03,
#          2.57849755e-02,  5.18973527e-02,  1.33454533e-01,
#          1.69579215e-01,  1.44807285e-01, -1.99346430e-03,
#         -2.34278506e-04,  5.40550611e-04,  2.61908397e-04,
#         -6.59549812e-02,  8.95862325e-03,  1.09882667e-01,
#         -5.78230826e-03,  3.97596050e-03, -6.94655075e-03,
#          3.37862037e-02,  1.14972507e-01,  3.96761818e-02,
#          1.69196530e-02, -6.59550680e-02,  3.30423800e-02,
#          1.20069118e-01,  3.67523369e-02,  2.38482875e-02,
#         -1.06116600e-01, -2.34800034e-01, -7.21148283e-02,
#         -1.45326912e-01, -2.21352047e-01, -8.01231826e-03,
#         -2.09807431e-01, -5.68798122e-02, -1.88642666e-01,
#         -2.18296567e-01, -1.06149060e-01, -2.35223838e-01,
#         -7.24626154e-02, -1.27466887e-01, -2.20986910e-01,
#          2.68797096e-02,  1.59860376e-01,  1.60479213e-01,
#          1.28714311e-01,  1.23112267e-01, -4.01377179e-03,
#          5.48292109e-02, -5.07211017e-03,  5.83157910e-02,
#         -2.62608982e-03,  3.52290367e-02,  1.32475506e-01,
#          7.97816531e-02,  1.12017031e-01,  9.99547816e-02,
#          4.65277206e-02, -2.12884033e-01, -2.35563401e-01,
#         -1.09095314e-01, -2.33162615e-01, -1.21638370e-01,
#          3.83373222e-02,  2.27215091e-02,  2.75104016e-02]])

# %%
df_comp = pd.DataFrame(pca_2.components_, columns=df_exclude_object.iloc[:,:-1].columns)

# %%
plt.figure(figsize = (12,6))
sns.heatmap(df_comp, cmap='plasma')
# Out:
# <Axes: >

# %%
# plot a scree plot
plt.plot(np.cumsum(pca_2.explained_variance_ratio_))
plt.xlabel('Number of Features')
plt.ylabel('Explained Variance')
# Out:
# Text(0, 0.5, 'Explained Variance')

# %% [markdown]
# ##Menjadi 22 principal components
# https://ieeexplore.ieee.org/abstract/document/9800807/

# %%
pca = PCA(n_components = 22) #mencari 2 principle components

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=22)

# %%
x_pca = pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (555278, 81)

# %%
x_pca.shape
# Out:
# (555278, 22)

# %%
pca.components_
# Out:
# array([[-0.00206883, -0.02891621,  0.08561276, ...,  0.17203985,
#          0.19280237, -0.02508562],
#        [ 0.04278872,  0.02579794, -0.07245122, ...,  0.03833731,
#          0.0227215 ,  0.02751041],
#        [-0.03830283, -0.03781454,  0.14516234, ..., -0.15193416,
#         -0.12450314, -0.04250071],
#        ...,
#        [-0.05762463, -0.03298985, -0.00390165, ..., -0.0003955 ,
#          0.01973753, -0.02199691],
#        [ 0.21100295,  0.09137019, -0.00489972, ..., -0.01317105,
#         -0.03411832, -0.01134211],
#        [ 0.29228233, -0.03596204, -0.00341398, ...,  0.05382529,
#          0.00199926,  0.09622098]])

# %%
df_comp = pd.DataFrame(pca.components_, columns=df_exclude_object.iloc[:,:-1].columns)

# %%
plt.figure(figsize = (12,6))
sns.heatmap(df_comp, cmap='plasma')
# Out:
# <Axes: >

# %%
# Sample figsize in inches
fig, ax = plt.subplots(figsize=(20,10))
# PCA DataFrame Correlation
corr = df_comp.corr()
sns.heatmap(corr, cmap='YlGnBu', annot_kws={'size':30}, ax=ax)
ax.set_title("PCA Correlation Matrix", fontsize=14)
plt.show()

# %%
# plot a scree plot
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('banyak komponen/feature')
plt.ylabel('Explained Variance')
# Out:
# Text(0, 0.5, 'Explained Variance')

# %% [markdown]
# #Classifications
# memakai x_pca sebagai x_train kita

# %%
from sklearn.model_selection import train_test_split
X = x_pca
y = df['Label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ##Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(max_iter=3000)

# %%
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=3000)

# %%
predLR = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, predLR))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97    155457
#            1       0.04      0.00      0.00     11127
#
#     accuracy                           0.93    166584
#    macro avg       0.49      0.50      0.48    166584
# weighted avg       0.87      0.93      0.90    166584

# %%
# confusion matrix
group_names = ['True Pos', 'False Pos', 'False Neg', 'True Neg']
test_cnf_matrix = confusion_matrix(y_test, predLR)
test_counts = ["{0:0.0f}".format(value) for value in test_cnf_matrix.flatten()]
test_percentage = ["{0:.2%}".format(value) for value in test_cnf_matrix .flatten()/np.sum(test_cnf_matrix)]
test_labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,test_counts,test_percentage)]
test_labels = np.asarray(test_labels).reshape(2,2)
plt.figure(figsize = (16,5))
sns.heatmap(test_cnf_matrix, annot=test_labels, fmt='', cmap='viridis');

# %% [markdown]
# ##KNN Classifier
# menggunakan n_neighbors default

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
predKNN = knn.predict(X_test)

# %%
print(classification_report(y_test, predKNN))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95    155457
#            1       0.28      0.20      0.23     11127
#
#     accuracy                           0.91    166584
#    macro avg       0.61      0.58      0.59    166584
# weighted avg       0.90      0.91      0.91    166584

# %%
# confusion matrix
group_names = ['True Pos', 'False Pos', 'False Neg', 'True Neg']
test_cnf_matrix = confusion_matrix(y_test, predKNN)
test_counts = ["{0:0.0f}".format(value) for value in test_cnf_matrix.flatten()]
test_percentage = ["{0:.2%}".format(value) for value in test_cnf_matrix .flatten()/np.sum(test_cnf_matrix)]
test_labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,test_counts,test_percentage)]
test_labels = np.asarray(test_labels).reshape(2,2)
plt.figure(figsize = (16,5))
sns.heatmap(test_cnf_matrix, annot=test_labels, fmt='', cmap='viridis');

# %% [markdown]
# ## Decision Tree dan Random Forest
# max_depth default, n_estimators default

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predDtree = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predDtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94    155457
#            1       0.11      0.10      0.10     11127
#
#     accuracy                           0.88    166584
#    macro avg       0.52      0.52      0.52    166584
# weighted avg       0.88      0.88      0.88    166584

# %%
# confusion matrix
group_names = ['True Pos', 'False Pos', 'False Neg', 'True Neg']
test_cnf_matrix = confusion_matrix(y_test, predDtree)
test_counts = ["{0:0.0f}".format(value) for value in test_cnf_matrix.flatten()]
test_percentage = ["{0:.2%}".format(value) for value in test_cnf_matrix .flatten()/np.sum(test_cnf_matrix)]
test_labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,test_counts,test_percentage)]
test_labels = np.asarray(test_labels).reshape(2,2)
plt.figure(figsize = (16,5))
sns.heatmap(test_cnf_matrix, annot=test_labels, fmt='', cmap='viridis');

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predRFC = rfc.predict(X_test)

# %%
print(classification_report(y_test, predRFC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94    155457
#            1       0.15      0.14      0.14     11127
#
#     accuracy                           0.89    166584
#    macro avg       0.54      0.54      0.54    166584
# weighted avg       0.89      0.89      0.89    166584

# %%
# confusion matrix
group_names = ['True Pos', 'False Pos', 'False Neg', 'True Neg']
test_cnf_matrix = confusion_matrix(y_test, predRFC)
test_counts = ["{0:0.0f}".format(value) for value in test_cnf_matrix.flatten()]
test_percentage = ["{0:.2%}".format(value) for value in test_cnf_matrix .flatten()/np.sum(test_cnf_matrix)]
test_labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,test_counts,test_percentage)]
test_labels = np.asarray(test_labels).reshape(2,2)
plt.figure(figsize = (16,5))
sns.heatmap(test_cnf_matrix, annot=test_labels, fmt='', cmap='viridis');

# %% [markdown]
# ##Naive Bayes: Gaussian Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
# Build a Gaussian Classifier
nbgc = GaussianNB()

# %%
# Model training
nbgc.fit(X_train, y_train)

# Predict Output
predNBGC = nbgc.predict(X_test)

# %%
print(classification_report(y_test, predNBGC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.37      0.54    155457
#            1       0.10      0.95      0.18     11127
#
#     accuracy                           0.41    166584
#    macro avg       0.54      0.66      0.36    166584
# weighted avg       0.93      0.41      0.52    166584

# %%
# confusion matrix
group_names = ['True Pos', 'False Pos', 'False Neg', 'True Neg']
test_cnf_matrix = confusion_matrix(y_test, predNBGC)
test_counts = ["{0:0.0f}".format(value) for value in test_cnf_matrix.flatten()]
test_percentage = ["{0:.2%}".format(value) for value in test_cnf_matrix .flatten()/np.sum(test_cnf_matrix)]
test_labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,test_counts,test_percentage)]
test_labels = np.asarray(test_labels).reshape(2,2)
plt.figure(figsize = (16,5))
sns.heatmap(test_cnf_matrix, annot=test_labels, fmt='', cmap='viridis');

# %% [markdown]
# ##SVC

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
'''
generalization:
low C = high bias, low variance
high C = low bias, low variance

low gamma = high variance
high gamma = low variance

gamma ada tergantung rbf
'''
# Out:
# '\ngeneralization:\nlow C = high bias, low variance\nhigh C = low bias, low variance\n\nlow gamma = high variance\nhigh gamma = low variance\n\ngamma ada tergantung rbf\n'

# %%
svc.fit(X_train, y_train)

# %%
pred_svc = svc.predict(X_test)

# %%
print(classification_report(y_test, pred_svc))

# %%
# confusion matrix
group_names = ['True Pos', 'False Pos', 'False Neg', 'True Neg']
test_cnf_matrix = confusion_matrix(y_test, pred_svc)
test_counts = ["{0:0.0f}".format(value) for value in test_cnf_matrix.flatten()]
test_percentage = ["{0:.2%}".format(value) for value in test_cnf_matrix .flatten()/np.sum(test_cnf_matrix)]
test_labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,test_counts,test_percentage)]
test_labels = np.asarray(test_labels).reshape(2,2)
plt.figure(figsize = (16,5))
sns.heatmap(test_cnf_matrix, annot=test_labels, fmt='', cmap='viridis');
